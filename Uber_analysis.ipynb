# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df= pd.read_csv('uber_data_sheet.csv')

# %%
df.head(5)
# Out:
#        id origin_taz destination_taz pickup_datetime  trip_distance  \
# 0  252581         7C              6A   9/1/2014 9:00           4.25
# 1  252582         7B              15  9/1/2014 18:00          10.17
# 2  252583         11              2A  9/1/2014 17:00           4.02
# 3  252584         3B              4A  9/1/2014 13:00           1.46
# 4  252585         2A              10  9/1/2014 14:00           8.31
#
#   trip_duration
# 0       0:15:11
# 1       0:34:05
# 2       0:17:06
# 3       0:06:32
# 4       0:26:17

# %%
df.shape[0]
# Out:
# 5021

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# id                   0
# origin_taz           0
# destination_taz    213
# pickup_datetime      0
# trip_distance        0
# trip_duration        0
# dtype: int64
